# %% [markdown]
# # Versão 07.09.2023

# %%
import os
import cv2
import pickle
import tkinter as tk
from tkinter import messagebox, filedialog
from PIL import Image, ImageTk
import face_recognition
from sklearn import svm
import time
import matplotlib.pyplot as plt
import numpy as np

class ReconhecimentoFacialApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Reconhecimento Facial Yale")

        # Centralize a janela principal
        window_width = 800
        window_height = 600
        screen_width = root.winfo_screenwidth()
        screen_height = root.winfo_screenheight()
        x = (screen_width - window_width) // 2
        y = (screen_height - window_height) // 2
        self.root.geometry(f"{window_width}x{window_height}+{x}+{y}")

        self.root.configure(bg="black")
        
        self.criar_widgets()

    def criar_widgets(self):
        self.criar_frame_titulo()
        self.criar_frame_botoes()
        self.criar_frame_resultado()

    def criar_frame_titulo(self):
        self.frame_titulo = tk.Frame(self.root, bg="black")
        self.frame_titulo.pack(pady=20)
        
        self.label_titulo = tk.Label(self.frame_titulo, text="Sistema de Reconhecimento Facial Yale", font=("Helvetica", 20), bg="black", fg="white")
        self.label_titulo.pack()

    def criar_frame_botoes(self):
        self.frame_botoes = tk.Frame(self.root, bg="black")
        self.frame_botoes.pack()

        self.botao_treinamento = tk.Button(self.frame_botoes, text="Treinamento", font=("Helvetica", 18), command=self.realizar_treinamento, bg="aquamarine", fg="black")
        self.botao_treinamento.pack(side=tk.LEFT, padx=10)

        self.botao_validacao_teste = tk.Button(self.frame_botoes, text="Validação/Teste", font=("Helvetica", 18), command=self.realizar_validacao_teste, bg="aquamarine", fg="black")
        self.botao_validacao_teste.pack(side=tk.LEFT, padx=10)
        
    def criar_frame_resultado(self):
        self.frame_resultado = tk.Frame(self.root, bg="black", highlightbackground="aquamarine", highlightthickness=2)
        self.frame_resultado.pack(pady=20)
        
        self.label_imagem_validacao = tk.Label(self.frame_resultado, bg="black", padx=10, pady=10)
        self.label_imagem_validacao.pack()

        self.label_mensagem_reconhecimento = tk.Label(self.frame_resultado, text="", bg="black", fg="white", font=("Helvetica", 16))
        self.label_mensagem_reconhecimento.pack()

        self.frame_icones = tk.Frame(self.frame_resultado, bg="black")
        self.frame_icones.pack(pady=10)

        self.fig, self.ax = plt.subplots()  
        self.ax.set_xlabel("Treinamento")
        self.ax.set_ylabel("Acurácia")
        self.acuracia_data = []

    def realizar_treinamento(self):
        self.botao_treinamento.config(state=tk.DISABLED)
        self.botao_validacao_teste.config(state=tk.DISABLED)

        print("Iniciando treinamento...")

        start_time = time.time()

        dataset_path = "src/YaleFaces"
        yale_encodings = []
        yale_labels = []
        imagens_treinadas = 0
        total_imagens = 0
        imagens_com_erro = []

        for subject_folder in os.listdir(dataset_path):
            subject_folder_path = os.path.join(dataset_path, subject_folder)
            if os.path.isdir(subject_folder_path):
                image_count = 0  # Conte o número de imagens por sujeito
                identity = subject_folder

                for img_name in os.listdir(subject_folder_path):
                    if img_name.endswith(".gif"):
                        image_count += 1
                        if image_count <= 7:  # Processar apenas as 7 primeiras imagens de cada sujeito
                            total_imagens += 1
                            image = face_recognition.load_image_file(os.path.join(subject_folder_path, img_name))

                            # Remoção de fundo usando OpenCV (BackgroundSubtractorMOG2)
                            image = self.remove_background(image)

                            # Aplicar aumento de dados (rotação e espelhamento)
                            augmented_images = self.augment_data(image)

                            for augmented_image in augmented_images:
                                encodings = face_recognition.face_encodings(augmented_image)
                                if encodings:
                                    encoding = encodings[0]
                                    yale_encodings.append(encoding)
                                    yale_labels.append(identity)
                                    imagens_treinadas += 1
                                    print(f"Face cadastrada: {identity}")
                                else:
                                    imagens_com_erro.append(os.path.join(subject_folder_path, img_name))
                                    print(f"Erro na imagem: {os.path.join(subject_folder_path, img_name)}")

        end_time = time.time()

        if not yale_encodings:
            messagebox.showerror("Erro de Treinamento", "Pelo menos duas identidades diferentes são necessárias para treinamento.")
            self.botao_treinamento.config(state=tk.NORMAL)
            self.botao_validacao_teste.config(state=tk.NORMAL)
            return

        svm_classifier = svm.SVC(kernel='linear', probability=True)
        svm_classifier.fit(yale_encodings, yale_labels)

        with open("modelo_classificador.pkl", "wb") as f:
            pickle.dump(svm_classifier, f)

        elapsed_time = end_time - start_time

        acuracia = imagens_treinadas / total_imagens
        print(f"Treinamento concluído em {elapsed_time:.2f} segundos.")
        print(f"Total de imagens percorridas: {total_imagens}")
        print(f"Imagens treinadas com sucesso: {imagens_treinadas}")
        print(f"Acurácia: {acuracia:.4f}")

        self.acuracia_data.append(acuracia)
        self.plot_acuracia()

        if imagens_com_erro:
            print("Imagens com erro:")
            for img_path in imagens_com_erro:
                print(img_path)

        messagebox.showinfo("Treinamento Concluído", "O treinamento foi concluído e o modelo foi salvo.")
        self.botao_treinamento.config(state=tk.NORMAL)
        self.botao_validacao_teste.config(state=tk.NORMAL)



    def realizar_validacao_teste(self):
        image_path = filedialog.askopenfilename(title="Selecionar Imagem", filetypes=[("Imagens", "*.gif")])
        if image_path:
            # Remova o frame de ícones existente e crie um novo
            self.frame_icones.destroy()
            self.frame_icones = tk.Frame(self.root, bg="black")
            self.frame_icones.pack()
            self.validar_reconhecimento(image_path)
    
    def validar_reconhecimento(self, image_path):
        if not os.path.exists("modelo_classificador.pkl"):
            messagebox.showerror("Erro", "Modelo não treinado. Realize o treinamento antes de fazer a validação/teste.")
            return

        with open("modelo_classificador.pkl", "rb") as f:
            svm_classifier = pickle.load(f)

        image = face_recognition.load_image_file(image_path)
        face_locations = face_recognition.face_locations(image)
        face_encodings = face_recognition.face_encodings(image, face_locations)

        if not face_encodings:
            #messagebox.showerror("Erro", "Nenhuma face foi encontrada na imagem.")
            self.label_mensagem_reconhecimento.config(text="Pessoa não reconhecida")
            self.mostrar_icone_x()
            # Mostrar a imagem original na label
            img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            img_pil = Image.fromarray(img_rgb)
            img_tk = ImageTk.PhotoImage(img_pil)
            self.label_imagem_validacao.config(image=img_tk)
            self.label_imagem_validacao.image = img_tk
            return

        predicted_labels = []
        for face_encoding in face_encodings:
            _label = svm_classifier.predict([face_encoding])
            predicted_labels.append(_label[0])

        img_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        img_pil = Image.fromarray(img_rgb)
        img_tk = ImageTk.PhotoImage(img_pil)
        self.label_imagem_validacao.config(image=img_tk)
        self.label_imagem_validacao.image = img_tk

        predicted_names = ", ".join(predicted_labels)
        if predicted_names:
            self.label_mensagem_reconhecimento.config(text=f"Pessoa Reconhecida: {predicted_names}")
            self.mostrar_icone_verificado()
        else:
            self.label_mensagem_reconhecimento.config(text="Pessoa não reconhecida")
            self.mostrar_icone_x()

        self.mostrar_resultado_reconhecimento(predicted_names)
      
    def remove_background(self, image):
        # Converta a imagem para tons de cinza
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # Aplique a segmentação de fundo
        _, mask = cv2.threshold(gray, 1, 255, cv2.THRESH_BINARY)

        # Aplique a máscara para remover o fundo
        result = cv2.bitwise_and(image, image, mask=mask)

        return result

    def augment_data(self, image):
        # Aplicar aumento de dados (rotação e espelhamento)
        augmented_images = []

        # Rotação em 45 graus
        for angle in [0, 45, 90, 135, 180, 225, 270, 315]:
            rotated_image = self.rotate_image(image, angle)
            augmented_images.append(rotated_image)

        # Espelhamento horizontal da imagem original
        mirrored_image = cv2.flip(image, 1)
        augmented_images.append(mirrored_image)

        return augmented_images


    def rotate_image(self, image, angle):
        center = tuple(np.array(image.shape[1::-1]) / 2)
        rot_mat = cv2.getRotationMatrix2D(center, angle, 1.0)
        result = cv2.warpAffine(image, rot_mat, image.shape[1::-1], flags=cv2.INTER_LINEAR)
        return result 

    def mostrar_resultado_reconhecimento(self, predicted_names):
        self.frame_icones.destroy()  # Remover o frame existente

        self.frame_icones = tk.Frame(self.frame_resultado, bg="black")
        self.frame_icones.pack(pady=10)

        if predicted_names:
            self.mostrar_icone_verificado()
        else:
            self.mostrar_icone_x()
            

    def mostrar_icone_verificado(self):
        # Crie e mostre o ícone de verificação
        icone_verificado = Image.open("icone_verificado.png")
        icone_verificado = icone_verificado.resize((100, 100))
        icone_verificado = ImageTk.PhotoImage(icone_verificado)
        label_icone = tk.Label(self.frame_icones, image=icone_verificado, bg="black")
        label_icone.image = icone_verificado
        label_icone.pack()

    def mostrar_icone_x(self):
        # Crie e mostre o ícone "X"
        icone_x = Image.open("icone_x.png")
        icone_x = icone_x.resize((100, 100))
        icone_x = ImageTk.PhotoImage(icone_x)
        label_icone = tk.Label(self.frame_icones, image=icone_x, bg="black")
        label_icone.image = icone_x
        label_icone.pack()


    def plot_acuracia(self):
        self.ax.clear()
        self.ax.set_xlabel("Treinamento")
        self.ax.set_ylabel("Acurácia")

        # Ajuste o tamanho da figura
        self.fig.set_size_inches(10, 6)  # Escolha as dimensões desejadas

        # Personalize o intervalo do eixo x (por exemplo, de 0 a 100)
        self.ax.set_xlim(0, len(self.acuracia_data) + 1)
        self.ax.set_xticks(range(0, len(self.acuracia_data) + 1, 10))  # Personalize os intervalos dos ticks se necessário

        self.ax.plot(range(1, len(self.acuracia_data) + 1), self.acuracia_data, marker='o')
        self.ax.set_ylim([0, 1])
        self.ax.grid(True)
        self.fig.canvas.draw()
    
        plt.show()


if __name__ == "__main__":
    root = tk.Tk()
    app = ReconhecimentoFacialApp(root)
    root.mainloop()
# Out:
# Iniciando treinamento...
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.centerlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.centerlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.centerlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.centerlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.centerlight.gif
# Face cadastrada: subject01
# Face cadastrada: subject01
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.glasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.glasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.glasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.glasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.glasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.glasses.gif
# Face cadastrada: subject01
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.happy.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.happy.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.happy.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.happy.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.happy.gif
# Face cadastrada: subject01
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.leftlight.gif
# Face cadastrada: subject01
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.noglasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.noglasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.noglasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.noglasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.noglasses.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.noglasses.gif
# Face cadastrada: subject01
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.normal.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.normal.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.normal.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.normal.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.normal.gif
# Face cadastrada: subject01
# Face cadastrada: subject01
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Erro na imagem: src/YaleFaces\subject01\subject01.rightlight.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.centerlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.centerlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.centerlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.centerlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.centerlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.centerlight.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.glasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.glasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.glasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.glasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.glasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.glasses.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.happy.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.happy.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.happy.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.happy.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.happy.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.happy.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.leftlight.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.noglasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.noglasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.noglasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.noglasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.noglasses.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.noglasses.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.normal.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.normal.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.normal.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.normal.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.normal.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.normal.gif
# Face cadastrada: subject02
# Face cadastrada: subject02
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Erro na imagem: src/YaleFaces\subject02\subject02.rightlight.gif
# Face cadastrada: subject02
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.centerlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.centerlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.centerlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.centerlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.centerlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.centerlight.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.happy.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.happy.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.happy.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.happy.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.happy.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.leftlight.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.noglasses.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.noglasses.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.noglasses.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.noglasses.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.noglasses.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.normal.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.normal.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.normal.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.normal.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.normal.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.rightlight.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject03
# Erro na imagem: src/YaleFaces\subject03\subject03.sad.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.sad.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.sad.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.sad.gif
# Erro na imagem: src/YaleFaces\subject03\subject03.sad.gif
# Face cadastrada: subject03
# Face cadastrada: subject03
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.centerlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.centerlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.centerlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.centerlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.centerlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.centerlight.gif
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.glasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.glasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.glasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.glasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.glasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.glasses.gif
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.happy.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.happy.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.happy.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.happy.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.happy.gif
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.leftlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.leftlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.leftlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.leftlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.leftlight.gif
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.noglasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.noglasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.noglasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.noglasses.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.noglasses.gif
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.normal.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.normal.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.normal.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.normal.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.normal.gif
# Face cadastrada: subject04
# Face cadastrada: subject04
# Face cadastrada: subject04
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Erro na imagem: src/YaleFaces\subject04\subject04.rightlight.gif
# Face cadastrada: subject04
# Face cadastrada: subject05
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.centerlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.centerlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.centerlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.centerlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.centerlight.gif
# Face cadastrada: subject05
# Face cadastrada: subject05
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.glasses.gif
# Face cadastrada: subject05
# Face cadastrada: subject05
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.happy.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.happy.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.happy.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.happy.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.happy.gif
# Face cadastrada: subject05
# Face cadastrada: subject05
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.leftlight.gif
# Face cadastrada: subject05
# Face cadastrada: subject05
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.noglasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.noglasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.noglasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.noglasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.noglasses.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.noglasses.gif
# Face cadastrada: subject05
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.normal.gif
# Face cadastrada: subject05
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Erro na imagem: src/YaleFaces\subject05\subject05.rightlight.gif
# Face cadastrada: subject05
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.centerlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.centerlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.centerlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.centerlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.centerlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.centerlight.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.happy.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.happy.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.happy.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.happy.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.happy.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.happy.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.leftlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.leftlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.leftlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.leftlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.leftlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.leftlight.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.noglasses.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.noglasses.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.noglasses.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.noglasses.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.noglasses.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.normal.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.normal.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.normal.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.normal.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.normal.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.rightlight.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject06
# Erro na imagem: src/YaleFaces\subject06\subject06.sad.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.sad.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.sad.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.sad.gif
# Erro na imagem: src/YaleFaces\subject06\subject06.sad.gif
# Face cadastrada: subject06
# Face cadastrada: subject06
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.centerlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.centerlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.centerlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.centerlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.centerlight.gif
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.glasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.glasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.glasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.glasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.glasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.glasses.gif
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.happy.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.happy.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.happy.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.happy.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.happy.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.happy.gif
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.leftlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.leftlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.leftlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.leftlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.leftlight.gif
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.noglasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.noglasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.noglasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.noglasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.noglasses.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.noglasses.gif
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.normal.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.normal.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.normal.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.normal.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.normal.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.normal.gif
# Face cadastrada: subject07
# Face cadastrada: subject07
# Face cadastrada: subject07
# Erro na imagem: src/YaleFaces\subject07\subject07.rightlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.rightlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.rightlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.rightlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.rightlight.gif
# Erro na imagem: src/YaleFaces\subject07\subject07.rightlight.gif
# Face cadastrada: subject07
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.centerlight.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.leftlight.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.noglasses.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.noglasses.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.noglasses.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.noglasses.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.noglasses.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.normal.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.rightlight.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.sad.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sad.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sad.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sad.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sad.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sad.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Face cadastrada: subject08
# Erro na imagem: src/YaleFaces\subject08\subject08.sleepy.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sleepy.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sleepy.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sleepy.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sleepy.gif
# Erro na imagem: src/YaleFaces\subject08\subject08.sleepy.gif
# Face cadastrada: subject08
# Face cadastrada: subject08
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.centerlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.centerlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.centerlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.centerlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.centerlight.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.glasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.glasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.glasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.glasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.glasses.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.happy.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.happy.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.happy.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.happy.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.happy.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.happy.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.leftlight.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.noglasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.noglasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.noglasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.noglasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.noglasses.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.noglasses.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.normal.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.normal.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.normal.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.normal.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.normal.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.normal.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject09
# Erro na imagem: src/YaleFaces\subject09\subject09.rightlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.rightlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.rightlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.rightlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.rightlight.gif
# Erro na imagem: src/YaleFaces\subject09\subject09.rightlight.gif
# Face cadastrada: subject09
# Face cadastrada: subject09
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.centerlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.centerlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.centerlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.centerlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.centerlight.gif
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.glasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.glasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.glasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.glasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.glasses.gif
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.happy.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.happy.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.happy.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.happy.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.happy.gif
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.leftlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.leftlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.leftlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.leftlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.leftlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.leftlight.gif
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.noglasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.noglasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.noglasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.noglasses.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.noglasses.gif
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.normal.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.normal.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.normal.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.normal.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.normal.gif
# Face cadastrada: subject10
# Face cadastrada: subject10
# Face cadastrada: subject10
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Erro na imagem: src/YaleFaces\subject10\subject10.rightlight.gif
# Face cadastrada: subject10
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.centerlight.gif
# Face cadastrada: subject11
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.glasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.glasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.glasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.glasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.glasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.glasses.gif
# Face cadastrada: subject11
# Face cadastrada: subject11
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.happy.gif
# Face cadastrada: subject11
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.leftlight.gif
# Face cadastrada: subject11
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.noglasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.noglasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.noglasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.noglasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.noglasses.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.noglasses.gif
# Face cadastrada: subject11
# Face cadastrada: subject11
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.normal.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.normal.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.normal.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.normal.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.normal.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.normal.gif
# Face cadastrada: subject11
# Face cadastrada: subject11
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Erro na imagem: src/YaleFaces\subject11\subject11.rightlight.gif
# Face cadastrada: subject11
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.centerlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.centerlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.centerlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.centerlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.centerlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.centerlight.gif
# Face cadastrada: subject12
# Face cadastrada: subject12
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.glasses.gif
# Face cadastrada: subject12
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.happy.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.happy.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.happy.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.happy.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.happy.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.happy.gif
# Face cadastrada: subject12
# Face cadastrada: subject12
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.leftlight.gif
# Face cadastrada: subject12
# Face cadastrada: subject12
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.noglasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.noglasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.noglasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.noglasses.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.noglasses.gif
# Face cadastrada: subject12
# Face cadastrada: subject12
# Face cadastrada: subject12
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.normal.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.normal.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.normal.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.normal.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.normal.gif
# Face cadastrada: subject12
# Face cadastrada: subject12
# Face cadastrada: subject12
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Erro na imagem: src/YaleFaces\subject12\subject12.rightlight.gif
# Face cadastrada: subject12
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.centerlight.gif
# Face cadastrada: subject13
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.glasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.glasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.glasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.glasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.glasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.glasses.gif
# Face cadastrada: subject13
# Face cadastrada: subject13
# Face cadastrada: subject13
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.happy.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.happy.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.happy.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.happy.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.happy.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.happy.gif
# Face cadastrada: subject13
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.leftlight.gif
# Face cadastrada: subject13
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.noglasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.noglasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.noglasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.noglasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.noglasses.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.noglasses.gif
# Face cadastrada: subject13
# Face cadastrada: subject13
# Face cadastrada: subject13
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.normal.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.normal.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.normal.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.normal.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.normal.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.normal.gif
# Face cadastrada: subject13
# Face cadastrada: subject13
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Erro na imagem: src/YaleFaces\subject13\subject13.rightlight.gif
# Face cadastrada: subject13
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.centerlight.gif
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.glasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.glasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.glasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.glasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.glasses.gif
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.happy.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.happy.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.happy.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.happy.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.happy.gif
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.leftlight.gif
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.noglasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.noglasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.noglasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.noglasses.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.noglasses.gif
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.normal.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.normal.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.normal.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.normal.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.normal.gif
# Face cadastrada: subject14
# Face cadastrada: subject14
# Face cadastrada: subject14
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Erro na imagem: src/YaleFaces\subject14\subject14.rightlight.gif
# Face cadastrada: subject14
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.centerlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.centerlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.centerlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.centerlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.centerlight.gif
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.glasses.gif
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.happy.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.happy.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.happy.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.happy.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.happy.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.happy.gif
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.leftlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.leftlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.leftlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.leftlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.leftlight.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.leftlight.gif
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.noglasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.noglasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.noglasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.noglasses.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.noglasses.gif
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.normal.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.normal.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.normal.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.normal.gif
# Erro na imagem: src/YaleFaces\subject15\subject15.normal.gif
# Face cadastrada: subject15
# Face cadastrada: subject15
# Face cadastrada: subject15
# Erro na imagem: src/YaleFaces\subject15\subject15.rightlight.gif
# ...
# src/YaleFaces\subject08\subject08.centerlight.gif
# src/YaleFaces\subject08\subject08.centerlight.gif
# src/YaleFaces\subject08\subject08.centerlight.gif
# src/YaleFaces\subject08\subject08.centerlight.gif
# src/YaleFaces\subject08\subject08.centerlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.leftlight.gif
# src/YaleFaces\subject08\subject08.noglasses.gif
# src/YaleFaces\subject08\subject08.noglasses.gif
# src/YaleFaces\subject08\subject08.noglasses.gif
# src/YaleFaces\subject08\subject08.noglasses.gif
# src/YaleFaces\subject08\subject08.noglasses.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.normal.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.rightlight.gif
# src/YaleFaces\subject08\subject08.sad.gif
# src/YaleFaces\subject08\subject08.sad.gif
# src/YaleFaces\subject08\subject08.sad.gif
# src/YaleFaces\subject08\subject08.sad.gif
# src/YaleFaces\subject08\subject08.sad.gif
# src/YaleFaces\subject08\subject08.sad.gif
# src/YaleFaces\subject08\subject08.sleepy.gif
# src/YaleFaces\subject08\subject08.sleepy.gif
# src/YaleFaces\subject08\subject08.sleepy.gif
# src/YaleFaces\subject08\subject08.sleepy.gif
# src/YaleFaces\subject08\subject08.sleepy.gif
# src/YaleFaces\subject08\subject08.sleepy.gif
# src/YaleFaces\subject09\subject09.centerlight.gif
# src/YaleFaces\subject09\subject09.centerlight.gif
# src/YaleFaces\subject09\subject09.centerlight.gif
# src/YaleFaces\subject09\subject09.centerlight.gif
# src/YaleFaces\subject09\subject09.centerlight.gif
# src/YaleFaces\subject09\subject09.glasses.gif
# src/YaleFaces\subject09\subject09.glasses.gif
# src/YaleFaces\subject09\subject09.glasses.gif
# src/YaleFaces\subject09\subject09.glasses.gif
# src/YaleFaces\subject09\subject09.glasses.gif
# src/YaleFaces\subject09\subject09.happy.gif
# src/YaleFaces\subject09\subject09.happy.gif
# src/YaleFaces\subject09\subject09.happy.gif
# src/YaleFaces\subject09\subject09.happy.gif
# src/YaleFaces\subject09\subject09.happy.gif
# src/YaleFaces\subject09\subject09.happy.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.leftlight.gif
# src/YaleFaces\subject09\subject09.noglasses.gif
# src/YaleFaces\subject09\subject09.noglasses.gif
# src/YaleFaces\subject09\subject09.noglasses.gif
# src/YaleFaces\subject09\subject09.noglasses.gif
# src/YaleFaces\subject09\subject09.noglasses.gif
# src/YaleFaces\subject09\subject09.noglasses.gif
# src/YaleFaces\subject09\subject09.normal.gif
# src/YaleFaces\subject09\subject09.normal.gif
# src/YaleFaces\subject09\subject09.normal.gif
# src/YaleFaces\subject09\subject09.normal.gif
# src/YaleFaces\subject09\subject09.normal.gif
# src/YaleFaces\subject09\subject09.normal.gif
# src/YaleFaces\subject09\subject09.rightlight.gif
# src/YaleFaces\subject09\subject09.rightlight.gif
# src/YaleFaces\subject09\subject09.rightlight.gif
# src/YaleFaces\subject09\subject09.rightlight.gif
# src/YaleFaces\subject09\subject09.rightlight.gif
# src/YaleFaces\subject09\subject09.rightlight.gif
# src/YaleFaces\subject10\subject10.centerlight.gif
# src/YaleFaces\subject10\subject10.centerlight.gif
# src/YaleFaces\subject10\subject10.centerlight.gif
# src/YaleFaces\subject10\subject10.centerlight.gif
# src/YaleFaces\subject10\subject10.centerlight.gif
# src/YaleFaces\subject10\subject10.glasses.gif
# src/YaleFaces\subject10\subject10.glasses.gif
# src/YaleFaces\subject10\subject10.glasses.gif
# src/YaleFaces\subject10\subject10.glasses.gif
# src/YaleFaces\subject10\subject10.glasses.gif
# src/YaleFaces\subject10\subject10.happy.gif
# src/YaleFaces\subject10\subject10.happy.gif
# src/YaleFaces\subject10\subject10.happy.gif
# src/YaleFaces\subject10\subject10.happy.gif
# src/YaleFaces\subject10\subject10.happy.gif
# src/YaleFaces\subject10\subject10.leftlight.gif
# src/YaleFaces\subject10\subject10.leftlight.gif
# src/YaleFaces\subject10\subject10.leftlight.gif
# src/YaleFaces\subject10\subject10.leftlight.gif
# src/YaleFaces\subject10\subject10.leftlight.gif
# src/YaleFaces\subject10\subject10.leftlight.gif
# src/YaleFaces\subject10\subject10.noglasses.gif
# src/YaleFaces\subject10\subject10.noglasses.gif
# src/YaleFaces\subject10\subject10.noglasses.gif
# src/YaleFaces\subject10\subject10.noglasses.gif
# src/YaleFaces\subject10\subject10.noglasses.gif
# src/YaleFaces\subject10\subject10.normal.gif
# src/YaleFaces\subject10\subject10.normal.gif
# src/YaleFaces\subject10\subject10.normal.gif
# src/YaleFaces\subject10\subject10.normal.gif
# src/YaleFaces\subject10\subject10.normal.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject10\subject10.rightlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.centerlight.gif
# src/YaleFaces\subject11\subject11.glasses.gif
# src/YaleFaces\subject11\subject11.glasses.gif
# src/YaleFaces\subject11\subject11.glasses.gif
# src/YaleFaces\subject11\subject11.glasses.gif
# src/YaleFaces\subject11\subject11.glasses.gif
# src/YaleFaces\subject11\subject11.glasses.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.happy.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.leftlight.gif
# src/YaleFaces\subject11\subject11.noglasses.gif
# src/YaleFaces\subject11\subject11.noglasses.gif
# src/YaleFaces\subject11\subject11.noglasses.gif
# src/YaleFaces\subject11\subject11.noglasses.gif
# src/YaleFaces\subject11\subject11.noglasses.gif
# src/YaleFaces\subject11\subject11.noglasses.gif
# src/YaleFaces\subject11\subject11.normal.gif
# src/YaleFaces\subject11\subject11.normal.gif
# src/YaleFaces\subject11\subject11.normal.gif
# src/YaleFaces\subject11\subject11.normal.gif
# src/YaleFaces\subject11\subject11.normal.gif
# src/YaleFaces\subject11\subject11.normal.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject11\subject11.rightlight.gif
# src/YaleFaces\subject12\subject12.centerlight.gif
# src/YaleFaces\subject12\subject12.centerlight.gif
# src/YaleFaces\subject12\subject12.centerlight.gif
# src/YaleFaces\subject12\subject12.centerlight.gif
# src/YaleFaces\subject12\subject12.centerlight.gif
# src/YaleFaces\subject12\subject12.centerlight.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.glasses.gif
# src/YaleFaces\subject12\subject12.happy.gif
# src/YaleFaces\subject12\subject12.happy.gif
# src/YaleFaces\subject12\subject12.happy.gif
# src/YaleFaces\subject12\subject12.happy.gif
# src/YaleFaces\subject12\subject12.happy.gif
# src/YaleFaces\subject12\subject12.happy.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.leftlight.gif
# src/YaleFaces\subject12\subject12.noglasses.gif
# src/YaleFaces\subject12\subject12.noglasses.gif
# src/YaleFaces\subject12\subject12.noglasses.gif
# src/YaleFaces\subject12\subject12.noglasses.gif
# src/YaleFaces\subject12\subject12.noglasses.gif
# src/YaleFaces\subject12\subject12.normal.gif
# src/YaleFaces\subject12\subject12.normal.gif
# src/YaleFaces\subject12\subject12.normal.gif
# src/YaleFaces\subject12\subject12.normal.gif
# src/YaleFaces\subject12\subject12.normal.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject12\subject12.rightlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.centerlight.gif
# src/YaleFaces\subject13\subject13.glasses.gif
# src/YaleFaces\subject13\subject13.glasses.gif
# src/YaleFaces\subject13\subject13.glasses.gif
# src/YaleFaces\subject13\subject13.glasses.gif
# src/YaleFaces\subject13\subject13.glasses.gif
# src/YaleFaces\subject13\subject13.glasses.gif
# src/YaleFaces\subject13\subject13.happy.gif
# src/YaleFaces\subject13\subject13.happy.gif
# src/YaleFaces\subject13\subject13.happy.gif
# src/YaleFaces\subject13\subject13.happy.gif
# src/YaleFaces\subject13\subject13.happy.gif
# src/YaleFaces\subject13\subject13.happy.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.leftlight.gif
# src/YaleFaces\subject13\subject13.noglasses.gif
# src/YaleFaces\subject13\subject13.noglasses.gif
# src/YaleFaces\subject13\subject13.noglasses.gif
# src/YaleFaces\subject13\subject13.noglasses.gif
# src/YaleFaces\subject13\subject13.noglasses.gif
# src/YaleFaces\subject13\subject13.noglasses.gif
# src/YaleFaces\subject13\subject13.normal.gif
# src/YaleFaces\subject13\subject13.normal.gif
# src/YaleFaces\subject13\subject13.normal.gif
# src/YaleFaces\subject13\subject13.normal.gif
# src/YaleFaces\subject13\subject13.normal.gif
# src/YaleFaces\subject13\subject13.normal.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject13\subject13.rightlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.centerlight.gif
# src/YaleFaces\subject14\subject14.glasses.gif
# src/YaleFaces\subject14\subject14.glasses.gif
# src/YaleFaces\subject14\subject14.glasses.gif
# src/YaleFaces\subject14\subject14.glasses.gif
# src/YaleFaces\subject14\subject14.glasses.gif
# src/YaleFaces\subject14\subject14.happy.gif
# src/YaleFaces\subject14\subject14.happy.gif
# src/YaleFaces\subject14\subject14.happy.gif
# src/YaleFaces\subject14\subject14.happy.gif
# src/YaleFaces\subject14\subject14.happy.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.leftlight.gif
# src/YaleFaces\subject14\subject14.noglasses.gif
# src/YaleFaces\subject14\subject14.noglasses.gif
# src/YaleFaces\subject14\subject14.noglasses.gif
# src/YaleFaces\subject14\subject14.noglasses.gif
# src/YaleFaces\subject14\subject14.noglasses.gif
# src/YaleFaces\subject14\subject14.normal.gif
# src/YaleFaces\subject14\subject14.normal.gif
# src/YaleFaces\subject14\subject14.normal.gif
# src/YaleFaces\subject14\subject14.normal.gif
# src/YaleFaces\subject14\subject14.normal.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject14\subject14.rightlight.gif
# src/YaleFaces\subject15\subject15.centerlight.gif
# src/YaleFaces\subject15\subject15.centerlight.gif
# src/YaleFaces\subject15\subject15.centerlight.gif
# src/YaleFaces\subject15\subject15.centerlight.gif
# src/YaleFaces\subject15\subject15.centerlight.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.glasses.gif
# src/YaleFaces\subject15\subject15.happy.gif
# src/YaleFaces\subject15\subject15.happy.gif
# src/YaleFaces\subject15\subject15.happy.gif
# src/YaleFaces\subject15\subject15.happy.gif
# src/YaleFaces\subject15\subject15.happy.gif
# src/YaleFaces\subject15\subject15.happy.gif
# src/YaleFaces\subject15\subject15.leftlight.gif
# src/YaleFaces\subject15\subject15.leftlight.gif
# src/YaleFaces\subject15\subject15.leftlight.gif
# src/YaleFaces\subject15\subject15.leftlight.gif
# src/YaleFaces\subject15\subject15.leftlight.gif
# src/YaleFaces\subject15\subject15.leftlight.gif
# src/YaleFaces\subject15\subject15.noglasses.gif
# src/YaleFaces\subject15\subject15.noglasses.gif
# src/YaleFaces\subject15\subject15.noglasses.gif
# src/YaleFaces\subject15\subject15.noglasses.gif
# src/YaleFaces\subject15\subject15.noglasses.gif
# src/YaleFaces\subject15\subject15.normal.gif
# src/YaleFaces\subject15\subject15.normal.gif
# src/YaleFaces\subject15\subject15.normal.gif
# src/YaleFaces\subject15\subject15.normal.gif
# src/YaleFaces\subject15\subject15.normal.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
# src/YaleFaces\subject15\subject15.rightlight.gif
